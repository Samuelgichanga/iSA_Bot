# %%
[
  {
    "tag": "about",
    "patterns": ["about iServe Africa", "background of iServe Africa", "mission of iServe Africa"],
    "responses": ["iServe Africa is an indigenous Kenyan gospel-driven organization that exists to promote faithful Bible teaching and servant leadership. It does this mainly through an apprenticeship programme for fresh graduates who are placed in churches and Christian community projects across Kenya with the aim of giving them experience and training in gospel ministry."]
  },
  {
    "tag": "vision_mission",
    "patterns": ["vision and mission", "purpose of iServe Africa"],
    "responses": ["The ministry of iServe Africa follows the pattern of the Apostle Paul who did not cling to his rights or his culture but made himself a servant of all (1 Corinthians 9). We place apprentices to be immersed in the life of the local Christian community. We encourage apprentices to be part of the small, the ordinary, the routine, and the long term of Christian ministry."]
  },
  {
    "tag": "program_details",
    "patterns": ["Utumishi Course", "apprenticeship program details"],
    "responses": ["Utumishi Course is a one-year Bible handling course aimed at equipping gospel workers with skills for faithful gospel work in their different ministry occupations."]
  },
  {
    "tag": "apprenticeship_experience",
    "patterns": ["experience as an apprentice", "benefits of apprenticeship"],
    "responses": ["There are great gains for those involved with iServe Africa as apprentices. We hold our placements and apprentices in very high esteem and seek to provide quality support through the staff and training, regular visits, and other resources."]
  },
  {
    "tag": "history",
    "patterns": ["founding of iServe Africa", "history of iServe Africa"],
    "responses": ["iServe Africa began in 2007 after Harrison spent two years in the UK as a ministry apprentice in Reading and Sussex. Through observation of the UK church landscape, training, and the personal mentoring he received, he became strongly convinced that the African church is in great need of gospel workers."]
  },
  {
    "tag": "legal_registration",
    "patterns": ["legal registration", "registration process"],
    "responses": ["In March 2011, iServe Africa was registered by the NGO Coordination Board as an International NGO (Registration Number OP.218/051/11-035/6919). In February 2014 a parallel registration, iServe Africa Gospel Society, was enacted under CAP 108 [The Societies Act], society number SOC/66336, registration number 43946."]
  },
  {
    "tag": "partnerships_support",
    "patterns": ["partnerships", "support for iServe Africa"],
    "responses": ["Upon his return from the UK in 2007, MTA provided the legal and institutional framework and hired Harrison to run the programme. They also provided support facilities like an office, a desk, and internet access. The Mission Awareness Committee of All Saints and St Richards Crowborough, besides adopting Harrison as a mission partner provided a laptop and some financial support."]
  },
  {
    "tag": "ministry_nature",
    "patterns": ["ministry nature", "nature of ministry"],
    "responses": ["The ministry of iServe Africa is pastoral. It aims to connect God's people with God's Mission through mobilization, recruitment, training, sending, and supporting Gospel workers for holistic transformation in Africa and beyond."]
  },
  {
    "tag": "impact",
    "patterns": ["impact of iServe Africa", "contribution of iServe Africa"],
    "responses": ["Over 300 apprentices have now been through the iServe apprenticeship programme. We hope and pray that by God's grace we might continue to grow this work by encouraging more churches to take apprenticeship as a training model."]
  },
  {
    "tag": "community_immersion",
    "patterns": ["community immersion", "role in local communities"],
    "responses": ["We believe in immersing apprentices in the life of the local Christian community, encouraging them to be part of the small, the ordinary, the routine, and the long term of Christian ministry. This helps them to identify with communities of all ages and all backgrounds."]
  },
  {
    "tag": "values",
    "patterns": ["values of iServe Africa", "core values"],
    "responses": ["We believe iServe Africa has a task to encourage a counter-cultural vision of sacrificial service. Our determination is to enable our apprentices both to grow in their knowledge and understanding of God and of His plans and purposes for their lives and also to contribute effectively during their year as apprentices."]
  }
]

# %%
import random
import json
import pickle
import numpy as np

import nltk
from nltk.stem import WordNetLemmatizer
from nltk.corpus import stopwords

from tensorflow.keras.models import load_model

# Download NLTK resources
nltk.download('punkt')
nltk.download('wordnet')
nltk.download('stopwords')

# Initialize WordNet lemmatizer and stopwords
lemmatizer = WordNetLemmatizer()
stop_words = set(stopwords.words('english'))

# Load intents and model
intents = json.loads(open('intents.json').read())
model = load_model('chatbot_model.h5')

# Load preprocessed data
words = pickle.load(open('words.pkl', 'rb'))
classes = pickle.load(open('classes.pkl', 'rb'))

def clean_up_sentence(sentence):
    # Tokenize the sentence
    sentence_words = nltk.word_tokenize(sentence)
    # Remove stopwords, lemmatize, and convert to lowercase
    sentence_words = [lemmatizer.lemmatize(word.lower()) for word in sentence_words if word.lower() not in stop_words]
    return sentence_words

def bow(sentence, words, show_details=False):
    # Tokenize the sentence
    sentence_words = clean_up_sentence(sentence)
    # Create bag of words
    bag = [0]*len(words)  
    for s in sentence_words:
        for i, w in enumerate(words):
            if w == s: 
                bag[i] = 1
                if show_details:
                    print ("found in bag: %s" % w)
    return(np.array(bag))

def predict_class(sentence):
    # Filter below threshold predictions
    p = bow(sentence, words, show_details=False)
    res = model.predict(np.array([p]))[0]
    ERROR_THRESHOLD = 0.7  # Adjust this threshold as needed
    results = [[i, r] for i, r in enumerate(res)]

    # Sort by strength of probability
    results.sort(key=lambda x: x[1], reverse=True)
   # print("Predictions:", results)  # Debug output
    
    return_list = []
    for r in results:
        if r[1] > ERROR_THRESHOLD:
            return_list.append({"intent": classes[r[0]], "probability": str(r[1])})
    return return_list

def get_response(ints, intents_json):
    if not ints:
        return "I'm sorry, I didn't understand that question. Could you please try asking in a different way?"
    else:
        tag = ints[0]['intent']
        list_of_intents = intents_json['intents']
        for i in list_of_intents:
            if(i['tag']== tag):
                result = random.choice(i['responses'])
                break
        return result

print("|============= Welcome to iServe Africa Inquiry Chatbot System! =============|")
print("|============================== Feel Free ============================|")
print("|================================== To ===============================|")
print("|=============== Ask your any query about iServe Africa ================|")

# Main interaction loop
while True:
    message = input("| You: ").lower()
    if message in ["bye", "goodbye"]:
        print("| Bot: Goodbye!")
        print("|===================== The Program Ends here! =====================|")
        break
    else:
        ints = predict_class(message)
        res = get_response(ints, intents)
        print("| Bot:", res)
# Out:
# WARNING:tensorflow:From C:\Users\gicha\anaconda3\lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\gicha\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\gicha\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\gicha\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# WARNING:tensorflow:From C:\Users\gicha\anaconda3\lib\site-packages\keras\src\backend.py:1398: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
#
# |============= Welcome to iServe Africa Inquiry Chatbot System! =============|
# |============================== Feel Free ============================|
# |================================== To ===============================|
# |=============== Ask your any query about iServe Africa ================|
# | You: begin
# 1/1 [==============================] - 0s 125ms/step
# | Bot: iServe Africa is a ministry that began in 2007 with a vision to train gospel workers for the African church. It was founded by Harrison after his experience as a ministry apprentice in the UK, where he observed the need for gospel workers in Africa. The organization focuses on equipping young Christians with the necessary skills, knowledge, and spiritual formation to serve effectively in various capacities within the church and society.
# | You: history
# 1/1 [==============================] - 0s 28ms/step
# | Bot: I'm sorry, I didn't understand that question. Could you please try asking in a different way?
# | You: History
# 1/1 [==============================] - 0s 25ms/step
# | Bot: I'm sorry, I didn't understand that question. Could you please try asking in a different way?
# | You: course
# 1/1 [==============================] - 0s 31ms/step
# | Bot: The Ministry Training Courses (MTCs) provide apprentices with training on how to study the Bible and teach it faithfully. Apprentices also serve in placements, supplementing the work of local churches and other organizations.
# | You: utumishi course
# 1/1 [==============================] - 0s 19ms/step
# | Bot: Utumishi Course is a one-year Bible handling course aimed at equipping gospel workers with skills for faithful gospel work in their different ministry occupations. It provides comprehensive training in areas such as biblical interpretation, theology, pastoral care, and leadership development.
# | You: funding
# 1/1 [==============================] - 0s 22ms/step
# | Bot: The iServe Africa UK Trust provides a channel for funding for tax-efficient giving from the UK. It is registered as a UK charity and a company limited by guarantee.
# | You: support
# 1/1 [==============================] - 0s 13ms/step
# | Bot: I'm sorry, I didn't understand that question. Could you please try asking in a different way?
# | You: apprentices
# 1/1 [==============================] - 0s 17ms/step
# | Bot: The apprenticeship program at iServe Africa offers training opportunities for young individuals interested in Christian ministry. Contact the regional ministry staff for information on apprenticeship intake and opportunities.
# | You: board of directors
# 1/1 [==============================] - 0s 16ms/step
# | Bot: iServe Africa is an organization committed to encouraging the raising up of a new generation of servant leaders and faithful Bible teachers. It is governed by a board of directors who provide oversight and policy direction. The daily affairs are managed by an executive director appointed by the board.
# | You: regional staffs
# 1/1 [==============================] - 0s 16ms/step
# | Bot: The regional ministry staff members include Joseph Wahome, Duncan Odera, Samson Muturi, Ben Kinuthia, Kenneth Mutuma, Kevin Moses, and Patrick Muhia.
# | You: list names of the apprentices and their placements
# 1/1 [==============================] - 0s 94ms/step
# | Bot: I'm sorry, I didn't understand that question. Could you please try asking in a different way?
# | You: apprentices
# 1/1 [==============================] - 0s 31ms/step
# | Bot: The apprenticeship program at iServe Africa offers training opportunities for young individuals interested in Christian ministry. Contact the regional ministry staff for information on apprenticeship intake and opportunities.
# | You: apprentices currently in the program
# 1/1 [==============================] - 0s 31ms/step
# | Bot: The apprenticeship program at iServe Africa offers training opportunities for young individuals interested in Christian ministry. Contact the regional ministry staff for information on apprenticeship intake and opportunities.
# | You: current apprentices
# 1/1 [==============================] - 0s 203ms/step
# | Bot: The apprenticeship program at iServe Africa offers training opportunities for young individuals interested in Christian ministry. Contact the regional ministry staff for information on apprenticeship intake and opportunities.
